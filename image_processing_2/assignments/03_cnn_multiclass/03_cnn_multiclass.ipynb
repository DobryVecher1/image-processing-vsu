# %% [markdown]
# # Мультиклассовая классификация с использованием Pytorch
#
# В этом задании вам предстоит решить задачу классификации используя фреймворк Pytorch. Необходимо выбрать **один из предлагаемых датасетов**:
#
# - Распознавание жестов [[Homepage](https://www.kaggle.com/datasets/ayuraj/asl-dataset)]
# - Классификация изображений медуз [[Homepage](https://www.kaggle.com/datasets/anshtanwar/jellyfish-types)]
#
# **Ссылки на скачивание датасетов вы сможете найти на странице задания в системе Moodle**.
#
# В папке помимо картинок вы найдете `.csv` файлы, в которых хранится информация о разбиении данных на тренировочную и валидационную части, а также метки класса, к которому изображения принадлежат.
#
# Вам необходимо реализовать полный цикл обучения, начиная с подготовки и загрузки данных, заканчивая созданием модели сверточной нейронной сети.

# %% [markdown]
# - Отобразите 2-3 картинки из датасета и подпишите соответствующий ей класс

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# YOUR CODE HERE

# %% [markdown]
# - Создайте объекты классов Dataset и Dataloaders

# %%
class CustomDataset(Dataset):
    def __init__(self):
        pass
    def __len__(self):
        pass
    def __getitem__(self, index: int):
        pass

# train_dataset = 
# val_dataset = 

# train_loader = 
# val_loader =

# %% [markdown]
# - Создайте модель сверточной нейронной сети. Вам понадобятся: сверточный слой, полносвязный слой, функция активации и pooling слой (очень глубокой архитектуру делать необязательно в данной задаче)

# %%
class CNNModel(nn.Module):
    def __init__(self):
        pass
    def forward(self, x):
        pass

# %% [markdown]
# - Реализуйте процесс обучения сети. На каждой эпохе необходимо выводить значения тренировочного и валидационного **лосса**, а также значение **метрики** (будем использовать метрику AUC-ROC; пользоваться готовыми реализациями метрик можно). Добейтесь качества на валидационном датасете не менее 80%.
#
# - В конце обучения постройте график зависимости лосса и метрик от номера эпохи.

# %%
def run_train(num_epochs):
    for epoch in range(num_epochs):
        pass

        # train loop
        
        # validation loop

# %% [markdown]
# ## Перед отправкой сохраните ноутбук с именем в следующем формате: **03_Фамилия.ipynb**
